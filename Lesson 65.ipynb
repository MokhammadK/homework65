# %%
import dlib
from imutils import face_utils
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread("C:\\Users\\Bruger\\Downloads\\titanic.jpg")

# %%
grey_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
grey_image.shape
# Out:
# (2082, 2560)

# %%
face_classifer = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
face = face_classifer.detectMultiScale(grey_image, scaleFactor=1.1, minNeighbors=5, minSize=(140, 140))

# %%
face
# Out:
# array([[375, 339, 798, 798]])

# %%
for (x, y, w, h) in face:
    cv2.rectangle(img, (x,y), (x+w, y+w), (0,0,255,), 4)

# %%
img_rgd = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize =(10,5))
plt.imshow(img_rgd)
plt.show()

# %%
img_hog = cv2.imread("C:\\Users\\Bruger\\Downloads\\titanic.jpg")
plt.imshow(img_hog)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
gray = cv2.imread("C:\\Users\\Bruger\\Downloads\\titanic.jpg", 0)
im = np.float32(gray) / 255.0
gx = cv2.Sobel(im, cv2.CV_32F, 1, 0, ksize=1)
gy = cv2.Sobel(im, cv2.CV_32F, 0, 1, ksize=1)
mag, angle = cv2.cartToPolar(gx, gy, angleInDegrees=True)

# %%
plt.imshow(mag)
plt.show()

# %%
face_detect = dlib.get_frontal_face_detector()
rects = face_detect(gray, 1)

for (i, rect) in enumerate(rects):
    (x, y, w, h) = face_utils.rect_to_bb(rect)
    cv2.rectangle(gray, (x, y), (x + w, y + h), (255, 255, 255), 3)
    
plt.figure(figsize=(10,6))
plt.imshow(gray, cmap='gray')
plt.show()
